# %%
import lightgbm as lgb
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('..\\data\\long_lat_bathy.txt',
                 header=0, names=['long', 'lat', 'bathy'])
print(df.head())

print(f'\nlength of dataset for weight: {len(df)}')
# Out:
#       long       lat        bathy
# 0 -130.392  47.07474 -2845.584229
# 1 -130.125  47.07474 -2697.497559
# 2 -129.859  47.07474 -2736.506348
# 3 -129.592  47.07474 -2698.546631
# 4 -129.325  47.07474 -2554.697510
#
# length of dataset for weight: 23

# %%
train_data = lgb.Dataset(df, label=df['bathy'], feature_name=['long', 'lat', 'bathy'], categorical_feature=['bathy'])

# %%
rng = np.random.default_rng()
w = rng.uniform(size=(23, ))
train_data.set_weight(w)

# %%
param = {'num_leaves': 31, 'objective': 'binary'}
param['metric'] = 'auc'

# %%
validation_data = train_data.create_valid(train_data)

# %%
lgb.train(params={
    'learning_rate': 0.1,
    'shrinkage_rate': 0.1,}, train_set=dtrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 3
#       1 lgb.train(params={
#       2     'learning_rate': 0.1,
# ----> 3     'shrinkage_rate': 0.1,}, train_set=dtrain)
#
# NameError: name 'dtrain' is not defined

# %%
train_data.save_binary('train_data.bin')
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Saving data to binary file train_data.bin
